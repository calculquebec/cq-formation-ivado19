# %%
type(2 ** 48)
# Out:
# int

# %%
type(2.0 ** 48)
# Out:
# float

# %%
type("2048")
# Out:
# str

# %%
import pandas as pd
df = pd.read_csv("data/surveys.csv")

# %%
df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
5 / 9
# Out:
# 0.5555555555555556

# %%
5 // 9
# Out:
# 0

# %%
10 // 3
# Out:
# 3

# %%
df['record_id'].dtype
# Out:
# dtype('int64')

# %%
df['record_id'] = df['record_id'].astype('float64')

# %%
df['record_id'].dtype
# Out:
# dtype('float64')

# %%
df['weight'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-215eb52c1ce0> in <module>
# ----> 1 df['weight'].astype('int64')
#
# /localscratch/user01.2.0/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# /localscratch/user01.2.0/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
df['weight'].mean()
# Out:
# 42.672428212991356

# %%
len(df[pd.isnull(df['weight'])])
# Out:
# 3266

# %%
df1 = df.copy()

df1['weight'] = df1['weight'].fillna(df['weight'].mean())

# %%
df1['weight'].mean()
# Out:
# 42.672428212991356

# %%
df_na = df.dropna()
df_na
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62          63.0      8   19  1977        3         DM   M             35.0
# 63          64.0      8   19  1977        7         DM   M             37.0
# 64          65.0      8   19  1977        4         DM   F             34.0
# 65          66.0      8   19  1977        4         DM   F             35.0
# 66          67.0      8   19  1977        7         DM   M             35.0
# 67          68.0      8   19  1977        8         DO   F             32.0
# 68          69.0      8   19  1977        2         PF   M             15.0
# 69          70.0      8   19  1977        3         OX   F             21.0
# 70          71.0      8   19  1977        7         DM   F             36.0
# 73          74.0      8   19  1977        8         PF   M             12.0
# 74          75.0      8   19  1977        8         DM   F             32.0
# ...

# %%
df_na.to_csv('no_na.csv', index=True)

# %%
df.dropna?

# %%
df[~df.isnull().any(axis=1)].shape
# Out:
# (30676, 9)
